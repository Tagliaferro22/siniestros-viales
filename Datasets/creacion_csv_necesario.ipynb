# %% [markdown]
# En este Jupyter Notebook, voy a crear el archivo CSV necesario para poder ver un mapa corplético en Power BI

# %%
import pandas as pd
comunas = pd.read_csv("comunas_dos.csv", encoding='latin', sep=";")
comunas
# Out:
#     id  objeto  comuna                                            barrios  \
# 0    1  COMUNA       1  CONSTITUCION, MONSERRAT, RETIRO, PUERTO MADERO...
# 1    2  COMUNA       2                                           RECOLETA
# 2    3  COMUNA       3                           SAN CRISTOBAL, BALVANERA
# 3    4  COMUNA       4    BARRACAS, BOCA, PARQUE PATRICIOS, NUEVA POMPEYA
# 4    5  COMUNA       5                                     ALMAGRO, BOEDO
# 5    6  COMUNA       6                                          CABALLITO
# 6    7  COMUNA       7                           FLORES, PARQUE CHACABUCO
# 7    8  COMUNA       8       VILLA LUGANO, VILLA RIACHUELO, VILLA SOLDATI
# 8    9  COMUNA       9              PARQUE AVELLANEDA, MATADEROS, LINIERS
# 9   10  COMUNA      10  FLORESTA, MONTE CASTRO, VELEZ SARSFIELD, VERSA...
# 10  11  COMUNA      11  VILLA DEL PARQUE, VILLA DEVOTO, VILLA GRAL. MI...
# 11  12  COMUNA      12  VILLA URQUIZA, VILLA PUEYRREDON, SAAVEDRA, COG...
# ...

# %%
comunas.columns
# Out:
# Index(['id', 'objeto', 'comuna', 'barrios', 'perimetro', 'area', 'geometry'], dtype='object')

# %% [markdown]
# Me voy a quedar sólo con las columnas:
# - Objeto
# - Comuna
# - Geometry

# %%
comunas = comunas[["objeto","comuna","geometry"]]
comunas
# Out:
#     objeto  comuna                                           geometry
# 0   COMUNA       1  MULTIPOLYGON (((-58.36854510004993 -34.5736498...
# 1   COMUNA       2  POLYGON ((-58.38000797143961 -34.5700234429082...
# 2   COMUNA       3  POLYGON ((-58.41192135079323 -34.5980025131251...
# 3   COMUNA       4  POLYGON ((-58.355205237293326 -34.619429373579...
# 4   COMUNA       5  POLYGON ((-58.41287241688502 -34.6141153251031...
# 5   COMUNA       6  POLYGON ((-58.43060751679444 -34.6070464102099...
# 6   COMUNA       7  POLYGON ((-58.451995869139076 -34.629744353719...
# 7   COMUNA       8  POLYGON ((-58.44913267354467 -34.6511641811902...
# 8   COMUNA       9  POLYGON ((-58.519251817573156 -34.633009260944...
# 9   COMUNA      10  POLYGON ((-58.488336526703186 -34.620159662624...
# 10  COMUNA      11  POLYGON ((-58.498383748409786 -34.596367555072...
# 11  COMUNA      12  POLYGON ((-58.50331004413224 -34.5938561392896...
# ...

# %% [markdown]
# Ahora voy a crear una nueva columna llamada "Comuna_completa" que sea de la forma: "Comuna X, CABA"

# %%
comuna_completa = []
for indice in comunas.index:
    comuna_completa.append(comunas["objeto"][indice] + " " + str(comunas["comuna"][indice]) + ", CABA")
    print(comuna_completa)
    break
# Out:
# ['COMUNA 1, CABA']

# %% [markdown]
# La salida es la esperada, por lo cuál decido escalarlo.

# %%
comuna_completa = []
for indice in comunas.index:
    comuna_completa.append(comunas["objeto"][indice] + " " + str(comunas["comuna"][indice]) + ", CABA")

print(comuna_completa)
# Out:
# ['COMUNA 1, CABA', 'COMUNA 2, CABA', 'COMUNA 3, CABA', 'COMUNA 4, CABA', 'COMUNA 5, CABA', 'COMUNA 6, CABA', 'COMUNA 7, CABA', 'COMUNA 8, CABA', 'COMUNA 9, CABA', 'COMUNA 10, CABA', 'COMUNA 11, CABA', 'COMUNA 12, CABA', 'COMUNA 13, CABA', 'COMUNA 14, CABA', 'COMUNA 15, CABA']

# %%
comunas["Comuna_completa"] = comuna_completa
comunas
# Out:
# C:\Users\crisr\AppData\Local\Temp\ipykernel_7876\835882937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comunas["Comuna_completa"] = comuna_completa
#     objeto  comuna                                           geometry  \
# 0   COMUNA       1  MULTIPOLYGON (((-58.36854510004993 -34.5736498...
# 1   COMUNA       2  POLYGON ((-58.38000797143961 -34.5700234429082...
# 2   COMUNA       3  POLYGON ((-58.41192135079323 -34.5980025131251...
# 3   COMUNA       4  POLYGON ((-58.355205237293326 -34.619429373579...
# 4   COMUNA       5  POLYGON ((-58.41287241688502 -34.6141153251031...
# 5   COMUNA       6  POLYGON ((-58.43060751679444 -34.6070464102099...
# 6   COMUNA       7  POLYGON ((-58.451995869139076 -34.629744353719...
# ...

# %% [markdown]
# Ahora voy a eliminar la primera columnas ya que me quedó inutilizable, la 2ª por su parte, puede usarse para conectarse con otras tablas.

# %%
comunas.drop(columns=["objeto"], inplace=True)
comunas
# Out:
# C:\Users\crisr\AppData\Local\Temp\ipykernel_7876\762619297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comunas.drop(columns=["objeto"], inplace=True)
#     comuna                                           geometry  Comuna_completa
# 0        1  MULTIPOLYGON (((-58.36854510004993 -34.5736498...   COMUNA 1, CABA
# 1        2  POLYGON ((-58.38000797143961 -34.5700234429082...   COMUNA 2, CABA
# 2        3  POLYGON ((-58.41192135079323 -34.5980025131251...   COMUNA 3, CABA
# 3        4  POLYGON ((-58.355205237293326 -34.619429373579...   COMUNA 4, CABA
# 4        5  POLYGON ((-58.41287241688502 -34.6141153251031...   COMUNA 5, CABA
# 5        6  POLYGON ((-58.43060751679444 -34.6070464102099...   COMUNA 6, CABA
# ...

# %% [markdown]
# Creo una columna adicional que va a contener la información acerca del país de dónde son las comunas.

# %%
comunas["Pais"] = "Argentina"
comunas
# Out:
# C:\Users\crisr\AppData\Local\Temp\ipykernel_7876\2160363596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comunas["Pais"] = "Argentina"
#     comuna                                           geometry  \
# 0        1  MULTIPOLYGON (((-58.36854510004993 -34.5736498...
# 1        2  POLYGON ((-58.38000797143961 -34.5700234429082...
# 2        3  POLYGON ((-58.41192135079323 -34.5980025131251...
# 3        4  POLYGON ((-58.355205237293326 -34.619429373579...
# 4        5  POLYGON ((-58.41287241688502 -34.6141153251031...
# 5        6  POLYGON ((-58.43060751679444 -34.6070464102099...
# 6        7  POLYGON ((-58.451995869139076 -34.629744353719...
# 7        8  POLYGON ((-58.44913267354467 -34.6511641811902...
# ...

# %% [markdown]
# Ahora voy a tratar de ver esta información en el dashboard de Power BI.
